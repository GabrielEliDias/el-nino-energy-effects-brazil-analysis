# %%
import pandas as pd

# %%
df_clima = pd.read_json("../data/raw/clima_historico_2015_2025.json")

df_clima.head(5)
# Out:
#                       latitude  longitude  generationtime_ms  \
# time                -15.782073  -47.88678         149.560452
# temperature_2m_mean -15.782073  -47.88678         149.560452
# precipitation_sum   -15.782073  -47.88678         149.560452
#
#                      utc_offset_seconds           timezone  \
# time                             -10800  America/Sao_Paulo
# temperature_2m_mean              -10800  America/Sao_Paulo
# precipitation_sum                -10800  America/Sao_Paulo
#
#                     timezone_abbreviation  elevation daily_units  \
# time                                GMT-3       1157     iso8601
# temperature_2m_mean                 GMT-3       1157          °C
# precipitation_sum                   GMT-3       1157          mm
#
#                                                                  daily
# time                 [2015-01-01, 2015-01-02, 2015-01-03, 2015-01-0...
# temperature_2m_mean  [23.9, 23.6, 23.5, 22.5, 22.9, 23.4, 23.3, 23....
# ...
